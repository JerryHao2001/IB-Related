# %% [markdown]
# <h4 id="Create-a-New-View-for-Output">Create a New View for Output<a class="anchor-link" href="#Create-a-New-View-for-Output">¶</a></h4>

# %% [markdown]
# <p>Display a FigureWidget and then create a new window to display it in so that you can scroll through your code but still keep an eye on what you're doing.</p>

# %% [markdown]
# <p><img src="https://raw.githubusercontent.com/michaelbabyn/plot_data/master/create_view_for_output_jupyter_lab.gif"/></p>
# <h4 id="View-Live-Updates">View Live Updates<a class="anchor-link" href="#View-Live-Updates">¶</a></h4><p>With the output view it is easy to take full advantage of FigureWidgets new impertive-style graph updates since you can see your code and your graph at the same time.</p>
# <p><img src="https://raw.githubusercontent.com/michaelbabyn/plot_data/master/demonstrate_view_jupyter_lab.gif"/></p>

# %% [markdown]
# <h4 id="Reference">Reference<a class="anchor-link" href="#Reference">¶</a></h4>

# %% [markdown]
# <p>See <a href="https://github.com/jonmmease/plotly_ipywidget_notebooks">these Jupyter notebooks</a> for even more FigureWidget examples.</p>
